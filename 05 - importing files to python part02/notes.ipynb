# %% [markdown]
# # lesson 01 :

# %% [markdown]
# ## Importing flat files from the web: your turn!

# %%
pip install beautifulsoup4
# Out:
# ...
#      |████████████████████████████████| 112kB 24.5MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

# %%
# Import package
from urllib.request import urlretrieve

# Import pandas
import pandas as pd

# Assign url of file: url
url = 'https://s3.amazonaws.com/assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

# Save file locally
urlretrieve(url , 'winequality-red.csv')

# Read file into a DataFrame and print its head
df = pd.read_csv('winequality-red.csv', sep=';')
print(df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## Opening and reading flat files from the web

# %%
# Import packages
import matplotlib.pyplot as plt
import pandas as pd

# Assign url of file: url

url = 'https://s3.amazonaws.com/assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'
# Read file into a DataFrame: df

df = pd.read_csv(url , sep = ';')
# Print the head of the DataFrame
print(df.head())

# Plot first column of df
pd.DataFrame.hist(df.iloc[:, 0:1])
plt.xlabel('fixed acidity (g(tartaric acid)/dm$^3$)')
plt.ylabel('count')
plt.show()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # Importing non-flat files from the web

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 112kB 19.5MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import package
import pandas as pd

# Assign url of file: url

url = 'http://s3.amazonaws.com/assets.datacamp.com/course/importing_data_into_r/latitude.xls'
# Read in all sheets of Excel file: xls
xls = pd.read_excel(url , sheet_name =None )

# Print the sheetnames to the shell
print(xls.keys())

# Print the head of the first sheet (using its name, NOT its index)

print(xls['1700'].head())
# Out:
# odict_keys(['1700', '1900'])
#                  country       1700
# 0            Afghanistan  34.565000
# 1  Akrotiri and Dhekelia  34.616667
# 2                Albania  41.312000
# 3                Algeria  36.720000
# 4         American Samoa -14.307000

# %%
url = 'http://health.canada.ca/apps/open-data/ebic/EBIC2010DrugCostEnglish.csv'

# %%
urlretrieve(url , 'drugcost.csv')
# Out:
# ('drugcost.csv', <http.client.HTTPMessage at 0x7fa54389c160>)

# %%
df = pd.read_csv('drugcost.csv'  , encoding='latin1')

# %%
df.columns
# Out:
# Index(['DiagnosticCategory', 'ICDChapter', 'CostType', 'CostSubtype', 'Year',
#        'Gender', 'AgeGroup', 'ProvinceTerritory', 'Cost'],
#       dtype='object')

# %%
df2 = df[['Year' , 'Gender' , 'AgeGroup' , 'Cost']]

# %%
df2.head(20)
# Out:
#     Year  Gender AgeGroup          Cost
# 0   2010  Female     0-14  8.872313e+03
# 1   2010  Female     0-14  6.732533e+03
# 2   2010  Female     0-14  8.272771e+03
# 3   2010  Female     0-14  4.669356e+03
# 4   2010    Male     0-14  1.127620e+06
# 5   2010    Male     0-14  2.078713e+04
# 6   2010    Male     0-14  4.051801e+05
# 7   2010    Male     0-14  5.074787e+04
# 8   2010    Male     0-14  2.550657e+04
# 9   2010  Female     0-14  6.711787e+03
# 10  2010  Female     0-14  8.429568e+03
# 11  2010  Female     0-14  4.585620e+03
# 12  2010    Male     0-14  5.708317e+05
# 13  2010    Male     0-14  5.931181e+04
# 14  2010    Male     0-14  1.846659e+05
# 15  2010    Male     0-14  1.827690e+05
# 16  2010    Male     0-14  1.419894e+05
# 17  2010    Male     0-14  9.091118e+05
# 18  2010  Female     0-14  4.044933e+04
# 19  2010  Female     0-14  3.410766e+04

# %%
import matplotlib.pyplot as plt

# %%
## Plot first column of df
pd.DataFrame.hist(df2.iloc[:,:])

plt.show()

# %% [markdown]
# ## Performing HTTP requests in Python using urllib

# %%
# Import packages

from urllib.request import urlopen , Request
# Specify the url
url = "http://www.datacamp.com/teach/documentation"

# This packages the request: request
request = Request("http://www.datacamp.com/teach/documentation")

# Sends the request and catches the response: response
response = urlopen(request)

# Print the datatype of response
print(type(response))

# Be polite and close the response!
response.close()
# Out:
# <class 'http.client.HTTPResponse'>

# %% [markdown]
# ## Printing HTTP request results in Python using urllib

# %%
# Import packages
from urllib.request import urlopen, Request

# Specify the url
url = "http://www.datacamp.com/teach/documentation"

# This packages the request
request = Request(url)

# Sends the request and catches the response: response

response = urlopen(request)
# Extract the response: html

html = response.read()
# Print the html
print(html)

# Be polite and close the response!
response.close()
# Out:
# b'<!doctype html>\n<html lang="en" data-direction="ltr">\n  <head>\n    <link href="https://fonts.intercomcdn.com" rel="preconnect" crossorigin>\n      <script src="https://www.googletagmanager.com/gtag/js?id=UA-39297847-9" async="async" nonce="/MwAyvi0V+0bMZBmjaL4MbAwyB7DZdqVVc0UFJZeECU="></script>\n      <script nonce="/MwAyvi0V+0bMZBmjaL4MbAwyB7DZdqVVc0UFJZeECU=">\n        window.dataLayer = window.dataLayer || [];\n        function gtag(){dataLayer.push(arguments);}\n        gtag(\'js\', new Date());\n        gtag(\'config\', \'UA-39297847-9\');\n</script>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <title>DataCamp Help Center</title>\n    <meta name="description" content="">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n      <link rel="alternate" href="http://instructor-support.datacamp.com/en/" hreflang="en">\n\n      <meta name="intercom:trackingEvent" content="{&quot;name&quot;:&quot;Viewed Help C
# ...

# %% [markdown]
# ## Performing HTTP requests in Python using requests

# %%
# Import package

import requests
# Specify the url: url
url = "http://www.datacamp.com/teach/documentation"
# Packages the request, send the request and catch the response: r

r = requests.get(url , 'r')
# Extract the response: text
text = r.text

# Print the html
print(text)
# Out:
# <!doctype html>
# <html lang="en" data-direction="ltr">
#   <head>
#     <link href="https://fonts.intercomcdn.com" rel="preconnect" crossorigin>
#       <script src="https://www.googletagmanager.com/gtag/js?id=UA-39297847-9" async="async" nonce="xMUBOCe5XfSp8r6PK0smWfM56krsING/Aq0b0N4hMmU="></script>
#       <script nonce="xMUBOCe5XfSp8r6PK0smWfM56krsING/Aq0b0N4hMmU=">
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'UA-39297847-9');
# </script>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>DataCamp Help Center</title>
#     <meta name="description" content="">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#       <link rel="alternate" href="http://instructor-support.datacamp.com/en/" hreflang="en">
#
# ...

# %% [markdown]
# ## example

# %%
urlx = 'http://collectionscanada.gc.ca/ourl/res.php?url_ver=Z39.88-2004&url_tim=2015-11-26T15%3A38%3A41Z&url_ctx_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Actx&rft_dat=1283390&rfr_id=info%3Asid%2Fcollectionscanada.gc.ca%3Apam&lang=eng'

# %%
# Import package

import requests
# Specify the url: url

# Packages the request, send the request and catch the response: r

r = requests.get(urlx , 'r')
# Extract the response: text
text = r.text

# Print the html
print(text)
# Out:
# <!DOCTYPE html><!--[if lt IE 9]><html class="no-js lt-ie9" lang="en" dir="ltr"><![endif]--><!--[if gt IE 8]><!-->
# <html class="no-js" lang="en" dir="ltr">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8">
# <!-- Web Experience Toolkit (WET) / Boîte à outils de l'expérience Web (BOEW)
# wet-boew.github.io/wet-boew/License-en.html / wet-boew.github.io/wet-boew/Licence-fr.html -->
# <title>Archives Search - Library and Archives Canada</title>
# <!-- SDC META START | DEBUT DES METADONNEES SDC -->
#
# <!-- SDC META END | FIN DES METADONNEES SDC -->
# <!-- METADATA BEGINS | DEBUT DES METADONNEES -->
# <meta name="description" content="Archives Search" />
# <meta name="dcterms.creator" content="Library and Archives Canada" />
# <meta name="dcterms.title" content="Archives Search - Library and Archives Canada" />
# <meta name="dcterms.issued" title="W3CDTF" content="2008-03-19">
# <meta name="dcterms.modified" title="W3CDTF" content="2016-02-12">
# ...

# %% [markdown]
# ## Parsing HTML with BeautifulSoup

# %%
pip install bs4
# Out:
# ...
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
urlx = 'http://collectionscanada.gc.ca/ourl/res.php?url_ver=Z39.88-2004&url_tim=2015-11-26T15%3A38%3A41Z&url_ctx_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Actx&rft_dat=1283390&rfr_id=info%3Asid%2Fcollectionscanada.gc.ca%3Apam&lang=eng'

# Package the request, send the request and catch the response: r
r = requests.get(urlx)

# Extracts the response as html: html_doc

html_doc = r.text
# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup = soup.prettify()

# Print the response
print(pretty_soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 9]><html class="no-js lt-ie9" lang="en" dir="ltr"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Web Experience Toolkit (WET) / Boîte à outils de l'expérience Web (BOEW)
# wet-boew.github.io/wet-boew/License-en.html / wet-boew.github.io/wet-boew/Licence-fr.html -->
#   <title>
#    Archives Search - Library and Archives Canada
#   </title>
#   <!-- SDC META START | DEBUT DES METADONNEES SDC -->
#   <!-- SDC META END | FIN DES METADONNEES SDC -->
#   <!-- METADATA BEGINS | DEBUT DES METADONNEES -->
#   <meta content="Archives Search" name="description"/>
#   <meta content="Library and Archives Canada" name="dcterms.creator"/>
#   <meta content="Archives Search - Library and Archives Canada" name="dcterms.title"/>
#   <meta content="2008-03-19" name="dcterms.issued" title="W3CDTF"/>
#   <meta content="2016-02-12" name="dcterms.modified" title="W3CDTF"/>
# ...

# %% [markdown]
# ## Turning a webpage into data using BeautifulSoup: getting the text

# %%
urlx = 'http://collectionscanada.gc.ca/ourl/res.php?url_ver=Z39.88-2004&url_tim=2015-05-29T12%3A44%3A35Z&url_ctx_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Actx&rft_dat=1283353&rfr_id=info%3Asid%2Fcollectionscanada.gc.ca%3Apam&lang=eng'

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url = 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r = requests.get(urlx)

# Extract the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Get the title of Guido's webpage: guido_title
title = soup.title

# Print the title of Guido's webpage to the shell

print(title)
# Get Guido's text: guido_text

text = soup.get_text()

# Print Guido's text to the shell
print(text)
# Out:
# <title>Archives Search - Library and Archives Canada</title>
#
#
#
# Archives Search - Library and Archives Canada
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <link rel="stylesheet" href="../../WTS/000/wet-boew4.0.2/css/noscript.min.css" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
#
#
# Skip to "About this site"
#
#
#
#
#
#
#
#
#
# Canada.ca
# Services
# Departments
# Language selection
#
#
# Français
#
#
#
#
# Search and menus
#
# Search and menus
#
#
#
#
#
#
#
#
#
#
# Library and Archives Canada
#
#
#
#
#
#
#
#
#
# Topics menu
#
#
# 	Discover the collection
# 	Online research
# 	Copies & visiting
# 	Services and programs
#
#
#
#
#
#
# You are here:
#
#
#
# Home
# Search
#
#
#
#
#
#
#
#
#
# Archives Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			Any Keyword(s):
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Search only:
#
#
# 		            Library,
#         		Archives Advanced Search,
#
#
#                     Ancestors,
#
#
# 		Images,
# 		Search All
#
# ...

# %% [markdown]
# ## Turning a webpage into data using BeautifulSoup: getting the hyperlinks

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url
url = 'https://www.python.org/~guido/'
urlx = 'http://collectionscanada.gc.ca/ourl/res.php?url_ver=Z39.88-2004&url_tim=2015-05-29T12%3A44%3A35Z&url_ctx_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Actx&rft_dat=1283353&rfr_id=info%3Asid%2Fcollectionscanada.gc.ca%3Apam&lang=eng'
# Package the request, send the request and catch the response: r
r = requests.get(urlx)

# Extracts the response as html: html_doc
html_doc = r.text

# create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Print the title of Guido's webpage
print(soup.title)

# Find all 'a' tags (which define hyperlinks): a_tags
a_tags = soup.find_all('a')

# Print the URLs to the shell
for link in a_tags:
    print(link.get('href'))
# Out:
# <title>Archives Search - Library and Archives Canada</title>
# #wb-cont
# #wb-info
# http://www.canada.ca/en/index.html
# http://www.canada.ca/en/services/index.html
# http://www.canada.ca/en/gov/dept/index.html
# http://collectionscanada.gc.ca/pam_archives/index.php?fuseaction=genitem.displayItem&lang=fre&rec_nbr=1283353
# #mb-pnl
# http://www.bac-lac.gc.ca/eng/Pages/home.aspx
# http://www.bac-lac.gc.ca/eng/pages/mega-menu.aspx?lvl=1
# http://www.bac-lac.gc.ca/eng/pages/mega-menu.aspx?lvl=2
# http://www.bac-lac.gc.ca/eng/pages/mega-menu.aspx?lvl=3
# http://www.bac-lac.gc.ca/eng/pages/mega-menu.aspx?lvl=4
# http://www.bac-lac.gc.ca/eng/Pages/home.aspx
# http://www.bac-lac.gc.ca/eng/search/Pages/search.aspx
# http://www.bac-lac.gc.ca/eng/search/Pages/library-search.aspx#aurora
# http://collectionscanada.gc.ca/lac-bac/search-recherche/arch-adv-elab.php?Language=eng
# http://www.bac-lac.gc.ca/eng/search/Pages/ancestors-search.aspx
# http://collectionscanada.gc.ca/lac-bac/search/images
# ...

# %%
urlx = 'http://collectionscanada.gc.ca/ourl/res.php?url_ver=Z39.88-2004&url_tim=2015-05-29T12%3A44%3A35Z&url_ctx_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Actx&rft_dat=1283353&rfr_id=info%3Asid%2Fcollectionscanada.gc.ca%3Apam&lang=eng'
# Package the request, send the request and catch the response: r
r = requests.get(urlx)

# Extracts the response as html: html_doc
html_doc = r.text

# create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Print the title of Guido's webpage
print(soup.title)

# Find all 'a' tags (which define hyperlinks): a_tags
a_tags = soup.find_all('section')
print(a_tags)
# Print the URLs to the shell
for link in a_tags:
    print(link.get('class'))
# Out:
# <title>Archives Search - Library and Archives Canada</title>
# [<section class="wb-mb-links col-xs-12 visible-sm visible-xs" id="wb-glb-mn">
# <h2>Search and menus</h2>
# <ul class="pnl-btn list-inline text-right">
# <li><a aria-controls="mb-pnl" class="overlay-lnk btn btn-sm btn-default" href="#mb-pnl" role="button" title="Search and menus"><span class="glyphicon glyphicon-search"><span class="glyphicon glyphicon-th-list"><span class="wb-inv">Search and menus</span></span></span></a></li>
# </ul>
# <div id="mb-pnl"></div>
# </section>, <section class="col-sm-3"><h3><a href="http://www.bac-lac.gc.ca/eng/about-us/Pages/about-us.aspx">About us</a></h3>
# <ul class="list-unstyled">
# <li><a href="http://www.bac-lac.gc.ca/eng/about-us/Pages/our-mandate.aspx">Our Mandate</a></li>
# <li><a href="http://www.bac-lac.gc.ca/eng/about-us/Pages/librarian-archivist-canada.aspx">Librarian and Archivist of Canada</a></li>
# ...

# %% [markdown]
# # lesson 02 :

# %% [markdown]
# ## Loading and exploring a JSON

# %%
import json

# %%
# Load JSON: json_data
with open("data.json") as json_file:
    json_data = json.load(json_file)

# Print each key-value pair in json_data
for k in json_data:
    print(k[:5])
# Out:
# ['organization', 'interaction_intervention_id', 'org_intervention_id', 'project_tags', 'project_name']
# ['#org+implementing+name', '#meta+id+interaction', '#meta+id+org', '#meta+tags', '#activity+name']
# ['Life for Relief and Development', 'LRD-EG-11-8726', '', 'foodsecurity_site', 'Food Distributions to Orphans and Poor Families in Egypt']
# ['Volunteers for Economic Growth Alliance (VEGA)', 'VEGA-EG-15-18714', '', 'foodsecurity_site', 'Egypt Feed the Future Food Security and Agribusiness Program']
# ['Volunteers for Economic Growth Alliance (VEGA)', 'VEGA-EG-16-18894', '', '', 'Feed the Future Egypt Food Security and Agribusiness Support Project']
# ['Trickle Up', '86-21166', '', '', 'Promoting the Economic Engagement of Refugees in Egypt']

# %% [markdown]
# ## API requests

# %%
# Import requests package

import requests
# Assign URL to variable: url
url = 'http://www.omdbapi.com/?apikey=72bc447a&t=the+social+network'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Print the text of the response

print(r.text)
# Out:
# {"Title":"The Social Network","Year":"2010","Rated":"PG-13","Released":"01 Oct 2010","Runtime":"120 min","Genre":"Biography, Drama","Director":"David Fincher","Writer":"Aaron Sorkin (screenplay), Ben Mezrich (book)","Actors":"Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons","Plot":"As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea, and by the co-founder who was later squeezed out of the business.","Language":"English, French","Country":"USA","Awards":"Won 3 Oscars. Another 168 wins & 177 nominations.","Poster":"https://m.media-amazon.com/images/M/MV5BOGUyZDUxZjEtMmIzMC00MzlmLTg4MGItZWJmMzBhZjE0Mjc1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"7.7/10"},{"Source":"Rotten Tomatoes","Value":"96%"},{"Source":"Metacritic","Value":"95/100"}],"Metascore":"95","imdbRating":"7.7","imdbVotes":"581,767","imdbID":"tt12
# ...

# %% [markdown]
# ## JSON–from the web to Python

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'http://www.omdbapi.com/?apikey=72bc447a&t=social+network'

# Package the request, send the request and catch the response: r

r = requests.get(url)
# Decode the JSON data into a dictionary: json_data

json_data = r.json()
# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Title:  The Social Network
# Year:  2010
# Rated:  PG-13
# Released:  01 Oct 2010
# Runtime:  120 min
# Genre:  Biography, Drama
# Director:  David Fincher
# Writer:  Aaron Sorkin (screenplay), Ben Mezrich (book)
# Actors:  Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons
# Plot:  As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea, and by the co-founder who was later squeezed out of the business.
# Language:  English, French
# Country:  USA
# Awards:  Won 3 Oscars. Another 168 wins & 177 nominations.
# Poster:  https://m.media-amazon.com/images/M/MV5BOGUyZDUxZjEtMmIzMC00MzlmLTg4MGItZWJmMzBhZjE0Mjc1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}, {'Source': 'Rotten Tomatoes', 'Value': '96%'}, {'Source': 'Metacritic', 'Value': '95/100'}]
# Metascore:  95
# imdbRating:  7.7
# imdbVotes:  581,767
# ...

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'http://www.omdbapi.com/?apikey=72bc447a&t=the'

# Package the request, send the request and catch the response: r

r = requests.get(url)
# Decode the JSON data into a dictionary: json_data

json_data = r.json()

# %%
json_data
# Out:
# {'Title': 'The Shawshank Redemption',
#  'Year': '1994',
#  'Rated': 'R',
#  'Released': '14 Oct 1994',
#  'Runtime': '142 min',
#  'Genre': 'Drama',
#  'Director': 'Frank Darabont',
#  'Writer': 'Stephen King (short story "Rita Hayworth and Shawshank Redemption"), Frank Darabont (screenplay)',
#  'Actors': 'Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler',
#  'Plot': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#  'Language': 'English',
#  'Country': 'USA',
#  'Awards': 'Nominated for 7 Oscars. Another 19 wins & 32 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.3/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#   {'Source': 'Metacritic', 'Value': '80/100'}],
#  'Metascore': '80',
#  'imdbRating': '9.3',
# ...

# %% [markdown]
# ## Checking out the Wikipedia API

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=pizza'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data

json_data = r.json()
# Print the Wikipedia page extract
pizza_extract = json_data['query']['pages']['24768']['extract']
print(pizza_extract)
# Out:
# <p class="mw-empty-elt">
# </p>
#
# <p><b>Pizza</b> (<small>Italian: </small><span title="Representation in the International Phonetic Alphabet (IPA)">[ˈpittsa]</span>, <small>Neapolitan: </small><span title="Representation in the International Phonetic Alphabet (IPA)">[ˈpittsə]</span>) is a savory dish of Italian origin, consisting of a usually round, flattened base of leavened wheat-based dough topped with tomatoes, cheese, and often various other ingredients (anchovies, olives, meat, etc.) baked at a high temperature, traditionally in a wood-fired oven. A small pizza is sometimes called a pizzetta.
# </p><p>In Italy, pizza served in formal settings, such as at a restaurant, is presented unsliced and eaten with the use of a knife and fork. In casual settings it is cut into wedges to be eaten while held in the hand.
# ...

# %% [markdown]
# ## API Authentication

# %%
pip install tweepy
# Out:
# ...
#      |████████████████████████████████| 153kB 3.9MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

# %%
# Import package

import tweepy
# Store OAuth authentication credentials in relevant variables
access_token = "247398281-rAtPXCH1cl156Zzqy8CKqNlNsgWbnDjHyxXllY2E"
access_token_secret = "RKAQNuSbrlolj9p5bjOXJH9C5jXn9g0f3hRrlXirc7fme"
consumer_key = "As7UgQKWZVD3hCbAZABPaijP3"
consumer_secret = "nTmV8sXm9NQkvdki4YHCMSVBPzdN81mc16YBtK6AJljYhHV49N"

# Pass OAuth details to tweepy's OAuth handler
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

auth.set_access_token(access_token , access_token_secret)

# %% [markdown]
# ## Streaming tweets

# %%
tweet_list = []

# %%
class MyStreamListener(tweepy.StreamListener):
    def __init__(self, api=None):
        super(MyStreamListener, self).__init__()
        self.num_tweets = 0
        self.file = open("tweets.txt", "w")
    def on_status(self, status):
        tweet = status._json
        self.file.write(json.dumps(tweet) + '\n')
        tweet_list.append(status)
        self.num_tweets += 1
        if self.num_tweets < 100:
            return True
        else:
            return False
            self.file.close()

# %%
# Initialize Stream listener
l = MyStreamListener()

# Create your Stream object with authentication
stream = tweepy.Stream(auth,l)

# Filter Twitter Streams to capture data by the keywords:
stream.filter(track = ['clinton' , 'trump' , 'sanders' , 'cruz'])

# %% [markdown]
# ## Load and explore your Twitter data

# %%
# Import package
import json

# String of path to file: tweets_data_path
tweets_data_path = 'tweets3.txt'

# Initialize empty list to store tweets: tweets_data

tweets_data = []
# Open connection to file
tweets_file = open(tweets_data_path, "r")

# Read in tweets and store in list: tweets_data
for line in tweet_list:
   
    tweets_data.append(line)


# Print the keys of the first tweet dict
print(tweets_data[0])
# Out:
# Status(_api=<tweepy.api.API object at 0x7f9559e38b70>, _json={'created_at': 'Wed Jan 01 16:43:12 +0000 2020', 'id': 1212413975910141954, 'id_str': '1212413975910141954', 'text': 'RT @tribelaw: As one of the originators of the idea of temporarily withholding the Articles of Impeachment from the Senate, I can say with…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 97035408, 'id_str': '97035408', 'name': 'Holly Bryan is recuperating', 'screen_name': 'hmbryan', 'location': 'Durham, NC', 'url': 'http://hollymbryan.tumblr.com', 'description': "Reader, Reviewer, Blogger at Book-Keeping | Feminist, Mom, Wife, Lawyer (inactive) | #endgunviolence #enddomesticviolence | Duke '97, UNC Law '01", 'translator_type': 'none', 'protected': False, 'verified
# ...

# %% [markdown]
# ## Twitter data to DataFrame

# %%
# Import package
import pandas as pd

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(tweets_data, columns=['text' , 'lang'])

# Print head of DataFrame
print(df.head())
# Out:
#                                                 text lang
# 0  RT @bpolitics: .@krollbondrating's Christopher...   en
# 1  RT @HeidiAlpine: @dmartosko Cruz video found.....   en
# 2  Njihuni me Zonjën Trump !!! | Ekskluzive https...   et
# 3  Your an idiot she shouldn't have tried to grab...   en
# 4  RT @AlanLohner: The anti-American D.C. elites ...   en

# %% [markdown]
# ## A little bit of Twitter text analysis

# %%
import re

def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)

    if match:
        return True
    return False

# %%
# Initialize list to store tweet counts
[clinton, trump, sanders, cruz] = [0, 0, 0, 0]

# Iterate through df, counting the number of tweets in which
# each candidate is mentioned
for index, row in df.iterrows():
    clinton += word_in_text('clinton', row['text'])
    trump += word_in_text('trump', row['text'])
    sanders += word_in_text('sanders', row['text'])
    cruz += word_in_text('cruz' , row['text'])

# %%
[clinton, trump, sanders, cruz]
# Out:
# [9, 77, 6, 14]

# %% [markdown]
# ## Plotting your Twitter data

# %%
# Import packages
import matplotlib.pyplot as plt 
import seaborn as sns


# Set seaborn style
sns.set(color_codes=True)

# Create a list of labels:cd
cd = ['clinton', 'trump', 'sanders', 'cruz']

print([clinton, trump, sanders, cruz])


# Plot the bar chart
ax = sns.barplot(cd, [clinton, trump, sanders, cruz])
ax.set(ylabel="count")
plt.show()
# Out:
# [9, 77, 6, 14]
